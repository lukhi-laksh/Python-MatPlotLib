# %% [markdown]
# # 1. Bar Plot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Normal Plot Chart

# %%
x = [1, 2, 3, 4]
y = [2, 4, 6, 8]

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Normal Bar chart With Color

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 4, 6, 8]


c = ['r', 'g', 'b', 'y']

plt.bar(x, y, color=c)
plt.show()

# %% [markdown]
# ## Bar plot with X and Y lable with Title

# %%
import matplotlib.pyplot as plt

x = ['Python', 'c', 'java', 'c++']
y = [85, 70, 60, 82]

plt.xlabel('Language', fontsize='10')
plt.ylabel('No.', fontsize='10')
plt.title('Languge demo', loc='left', fontsize='20')
plt.grid(False)

c = ['y', 'r', 'm', 'g']
plt.bar(x, y, width=0.4, color=c, align='edge',edgecolor='r',linewidth=5, linestyle='--', alpha=0.5) # color = 'r' --> all colums are red , # Aligh bydefault 'cetner' # for blur use = alpha and alpha value is only possible between 0 to 1 #

plt.show()

# %%
import matplotlib.pyplot as plt

x = ['Python', 'c', 'java', 'c++']
y = [85, 70, 60, 82]

plt.xlabel('Language', fontsize='10')
plt.ylabel('No.', fontsize='10')
plt.title('Languge demo', loc='left', fontsize='20')
plt.grid(False)

plt.bar(x, y, width=0.4, color=c, edgecolor='r', label="laksh") # after lable always use 'legend()' to show label

plt.legend(loc=9, facecolor="green", edgecolor="yellow", framealpha=0.5, shadow=True)

plt.show()

# %%
import matplotlib.pyplot as plt

x = ['Python', 'c', 'java', 'c++']
y = [85, 70, 60, 82]
z = [40, 30, 20, 50]

plt.xlabel('Language', fontsize='10')
plt.ylabel('No.', fontsize='10')
plt.title('Languge demo', loc='left', fontsize='20')
plt.grid(False)

# Two Line in same column
plt.bar(x, y, width=0.4, color='g', label="laksh") 
plt.bar(x, z, width=0.4, color='r', label="laksh1")

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ['Python', 'c', 'java', 'c++']
y = [85, 70, 60, 82]
z = [40, 30, 20, 50]

width = 0.2
p = np.arange(len(x))
p1 = [j + width for j in p]

plt.xlabel('Language', fontsize='10')
plt.ylabel('No.', fontsize='10')
plt.title('Languge demo', loc='left', fontsize='20')
plt.grid(False)

# if we don't want overlap but side by side then...
plt.bar(p, y, width, color='g', label="laksh") 
plt.bar(p1, z, width, color='r', label="laksh1")

plt.xticks(p + (width / 2), x, rotation=10)
plt.legend()
plt.show()

# %% [markdown]
# ## Zorizontal Chart

# %%
import matplotlib.pyplot as plt

x = ['Python', 'c', 'java', 'c++']
y = [85, 70, 60, 82]
z = [40, 30, 20, 50]

plt.xlabel('Language', fontsize='10')
plt.ylabel('No.', fontsize='10')
plt.title('Languge demo', loc='left', fontsize='20')
plt.grid(False)

# remove Width
plt.barh(x, y, color='g', label="laksh") 
plt.barh(x, z, color='r', label="laksh1")

plt.legend()
plt.show()

# %% [markdown]
# # 2. Scatter Plot

# %%
import matplotlib.pyplot as plt

day = [1, 2, 3, 4, 5, 6, 7]
no = [2, 3, 1, 4, 5, 3, 6]
c = ['g', 'g', 'b', 'g', 'y', 'r', 'g']
sisi = [500, 40, 30, 20, 10, 30, 40]

plt.scatter(day, no, color = c, s=sisi, alpha=0.5, marker='*', edgecolors='r', linewidths=2) # s stands for size, we can do only s = 15 for all # markers are ['.', ',', 'o', 'v', '^', '<', '>', '1', '2', '3', '4','s', 'p', '*', 'h', 'H', '+', 'x', 'X', 'D', 'd', '|', '_', 'P']

plt.title('Scatter Plot', fontsize='20')
plt.xlabel('Day', fontsize='10')
plt.ylabel('No', fontsize='10')
plt.show()

# %% [markdown]
# # 3. Histogram Plot

# %% [markdown]
# ## Only for generate rendom value

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(10, 60, (50)) # data value between 10 to 60 and size of array is 50

# %%
no = [30, 43, 11, 53, 13, 13, 47, 15, 42, 10, 20, 28, 20, 52, 32, 59, 59, 10, 40, 11,
      27, 16, 39, 39, 59, 21, 29, 10, 21, 27, 45, 47, 24, 45, 12, 54, 36, 23, 36, 53,
      26, 49, 35, 32, 53, 11, 11, 16, 25, 12]
l = [10, 20, 30, 40, 50, 60]

plt.hist(x, color='g', bins=l, edgecolor='r', histtype='stepfilled', label='python') # Adugest perefect in bottom side used bins # histotype override edgecolor# histotype = step, stepfilled, barstacked, bar # Histotype and rwidth not use together

plt.title('laksh', fontsize=20)
plt.xlabel('python', fontsize=10)
plt.ylabel('no', fontsize=10)
plt.axvline(45, color='b', label='line')
plt.legend(loc='upper right', fontsize=10) # upper left, upper right, lower left, lower right || upper center, lower center, center left, center right


plt.show()

# %% [markdown]
# ## Horizontal Histogram plot

# %%
no = [30, 43, 11, 53, 13, 13, 47, 15, 42, 10, 20, 28, 20, 52, 32, 59, 59, 10, 40, 11,
      27, 16, 39, 39, 59, 21, 29, 10, 21, 27, 45, 47, 24, 45, 12, 54, 36, 23, 36, 53,
      26, 49, 35, 32, 53, 11, 11, 16, 25, 12]
l = [10, 20, 30, 40, 50, 60]

plt.hist(x, color='g', bins=l, edgecolor='r', orientation='horizontal') # Bydefault orientation is set to vertical

# fontsize = # xx-small, x-small, small, medium, large, x-large, xx-large

plt.title('laksh', fontsize=20)
plt.xlabel('python', fontsize=10)
plt.ylabel('no', fontsize=10)

plt.show()

# %% [markdown]
# # 4. Pie Plot

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = ['python', 'c', 'c++', 'java']
ex = [0.2, 0.0, 0.0, 0.0]
c = ['r', 'g', 'b', 'y']

plt.pie(x, labels=y, explode=ex, colors=c, autopct='%0.1f%%', shadow=True, radius=1, labeldistance=1.1, startangle=0
        , textprops= {'fontsize': 14,'color': 'black','weight': 'bold','family': 'serif','style': 'italic'}, counterclock=True
        , wedgeprops = {'edgecolor': 'black','linewidth': 2,'linestyle': ':','width': 1.1}
) # write persentage, 0.'1' is number after point and second % is 10.0'%'<--

plt.title('Lukhi')
plt.legend(loc = 2)
plt.show()

# %%
plt.pie([1])
plt.show()

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
x1 = [40, 30, 20, 10]
y = ['python', 'c', 'c++', 'java']
c = ['c', 'brown', 'green', 'y']

plt.pie(x, labels=y, radius=1.1)
plt.pie(x1, radius=0.8, colors=c)

plt.show()

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = ['python', 'c', 'c++', 'java']


plt.pie(x, labels=y, radius=1.1)
plt.pie([1], colors='w', radius=0.8)

plt.show()

# %% [markdown]
# # 5. Stems Plot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [2, 2, -5, 7, -4, 3]

plt.stem(x, y, linefmt='-', markerfmt='ro', bottom=0, basefmt='g', label='python', orientation='vertical')
plt.legend()
plt.show()

# %% [markdown]
# # 6. Box Vs Whisker Plot

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40, 50, 60, 70, 80]
y = [20, 30, 40, 50, 60, 70, 80, 90]

p = [x, y]

plt.boxplot(p, notch=False, vert=True, widths=0.2, labels=['python', 'c'], patch_artist='True')# vert stand for vertical # patch_artist fill color 

plt.show()
# Out:
# C:\Users\luxlu\AppData\Local\Temp\ipykernel_26520\1279871327.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(p, notch=False, vert=True, widths=0.2, labels=['python', 'c'], patch_artist='True')# vert stand for vertical # patch_artist fill color

# %% [markdown]
# # 7. Stack Plot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 2, 5, 4]
z = [2, 3, 4, 5, 6]
a = [1, 3, 2, 4, 2]
l = ['area 1', 'area 2', 'area 3', 'area 4', 'area 5']
c = ['r', 'g', 'b']

plt.stackplot(x, y, z, a, labels=l, colors=c)

plt.title('laksh titiel')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.legend()
plt.show()

# %% [markdown]
# # 8. Step Plot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 2, 3, 5, 4]

plt.step(x, y, color='r', marker = 'o', ms = 10, mfc = 'g', label='python') # ms stand for size of .(dot) 

plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.grid()
plt.legend(loc = 4)
plt.show()

# %% [markdown]
# # 9. SubPlot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [1, 2, 3, 4]
plt.subplot(2, 2, 1)
plt.plot(x, y, color="r")

plt.subplot(2, 2, 2)
plt.pie([1], colors="r")

x1 = [10, 20, 30, 40]
plt.subplot(2, 2, 3)
plt.pie(x1)

x2 = ["a", "s", "d", "f"]
y2 = [10, 20, 30, 40]
plt.subplot(2, 2, 4)
plt.bar(x2, y2)

plt.show()

# %% [markdown]
# # 10. MatPlotLib Saving

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 2, 5, 4]
z = [2, 3, 4, 5, 6]
a = [1, 3, 2, 4, 2]
l = ['area 1', 'area 2', 'area 3', 'area 4', 'area 5']
c = ['r', 'g', 'b']

plt.stackplot(x, y, z, a, labels=l, colors=c)

plt.title('laksh titiel')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.legend()

plt.savefig('tran.pdf', dpi = 2000, facecolor = 'y', transparent = True) # save file sem directory
plt.show()

# %% [markdown]
# # 11. Add text in Chart

# %%
x = [1, 2, 3, 4, 5]
y = [3, 1, 5, 2, 6]

plt.plot(x, y)

plt.title("Wscube", fontsize=15)
plt.xlabel("Days", fontsize=15)
plt.ylabel("Python", fontsize=15)

plt.text(2, 5, "java", fontsize=15, style="italic", bbox={"facecolor": "red"})

plt.annotate("python", xy=(3, 2), xytext=(4, 4),
             arrowprops=dict(facecolor="black", shrink=200))

plt.show()
